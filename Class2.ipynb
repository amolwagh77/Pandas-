# %%
import pandas as pd

# %%
df=pd.read_csv('gapminder.csv',index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, Afghanistan to Zimbabwe
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        1704 non-null   int64
#  1   population  1704 non-null   int64
#  2   continent   1704 non-null   object
#  3   life_exp    1704 non-null   float64
#  4   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 79.9+ KB

# %%
df.head(3)
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df["life_exp"].max()
# Out:
# 82.603

# %% [markdown]
# ##### HOW TO FILTER SPECIFC ROWS FROM DATAFARAME

# %%
#I’m interested in the passengers older than 35 years.
above_35=df["life_exp"]>35
above_35
# Out:
# country
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan    False
# Afghanistan     True
#                ...
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Zimbabwe        True
# Name: life_exp, Length: 1704, dtype: bool

# %%
df[df['life_exp']>35]
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1671 rows x 5 columns]

# %%
# im intrested in country whos continent is asia and europe

df[df['continent'].isin(['Asia','Europe'])]
# Out:
#              year  population continent  life_exp      gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801   779.445314
# Afghanistan  1957     9240934      Asia    30.332   820.853030
# Afghanistan  1962    10267083      Asia    31.997   853.100710
# Afghanistan  1967    11537966      Asia    34.020   836.197138
# Afghanistan  1972    13079460      Asia    36.088   739.981106
# ...           ...         ...       ...       ...          ...
# Yemen, Rep.  1987    11219340      Asia    52.922  1971.741538
# Yemen, Rep.  1992    13367997      Asia    55.599  1879.496673
# Yemen, Rep.  1997    15826497      Asia    58.020  2117.484526
# Yemen, Rep.  2002    18701257      Asia    60.308  2234.820827
# Yemen, Rep.  2007    22211743      Asia    62.698  2280.769906
#
# [756 rows x 5 columns]

# %%
x=df[df['population'].notna()] # it returns a true for each row the values are not a Null
x
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(x='gdp_cap',y='life_exp')
# Out:
# <Axes: xlabel='gdp_cap'>

# %%
df.plot.scatter(y='gdp_cap',x='life_exp',alpha=0.5)
# Out:
# <Axes: xlabel='life_exp', ylabel='gdp_cap'>

# %%
 
show_plt=df.loc[:,['year','continent']]
show_plt
# Out:
#              year continent
# country
# Afghanistan  1952      Asia
# Afghanistan  1957      Asia
# Afghanistan  1962      Asia
# Afghanistan  1967      Asia
# Afghanistan  1972      Asia
# ...           ...       ...
# Zimbabwe     1987    Africa
# Zimbabwe     1992    Africa
# Zimbabwe     1997    Africa
# Zimbabwe     2002    Africa
# Zimbabwe     2007    Africa
#
# [1704 rows x 2 columns]

# %%
show_plt.plot.box()
# Out:
# <Axes: >
